# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('EnjoySport.csv')

X=data.iloc[:, :-1].values
y=data.iloc[:, -1].values

S=X[0].copy()
G=[["?" for _ in S] for _ in S]

print("Intital S : ",S)
print("Intital G : ",G)
# Out:
# Intital S :  ['Sunny' 'Warm' 'High' 'Strong' 'Warm' 'Same']
# Intital G :  [['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?']]

# %%
for i in range(len(X)):
    sample = X[i]

    if y[i]=='Yes':
        for j in range(len(S)):
            if sample[j]!=S[j]:
                S[j]='?'
                G[j] = ['?'] * len(S)
            
    else :
        for j in range(len(S)):
            if sample[j]!=S[j]:
                G[j][j] = S[j]
            else :
                G[j][j]='?'
        
    print(f"Step {i+1}: ")
    print("S:", S)
    print("G:", G)
# Out:
# Step 1:
# S: ['Sunny' 'Warm' 'High' 'Strong' 'Warm' 'Same']
# G: [['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?']]
# Step 2:
# S: ['Sunny' 'Warm' 'High' 'Strong' 'Warm' 'Same']
# G: [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', 'Same']]
# Step 3:
# S: ['Sunny' 'Warm' 'High' 'Strong' '?' '?']
# G: [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?'], ['?', '?', '?', '?', '?', '?']]

# %%
G = [g for g in G if g != ['?']*len(S)]

print("Final S:", S)
print("Final G:", G)
# Out:
# Final S: ['Sunny' 'Warm' 'High' 'Strong' '?' '?']
# Final G: [['Sunny', '?', '?', '?', '?', '?'], ['?', 'Warm', '?', '?', '?', '?']]
